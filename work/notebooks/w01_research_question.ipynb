# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/bhuvanteja-0722/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
# !git clone https://github.com/bhuvanteja-0722/flyrank-ml-internship.git
# Out:
# fatal: destination path 'flyrank-ml-internship' already exists and is not an empty directory.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Lane: Refresh / Content Opportunity Scoring. I want to identify which pages should be reviewed first for a possible content refresh. This lane is useful because the dataset contains observable signals about content age, search visibility, position, and engagement. A ranked review list could help the team spend limited content resources on pages that appear most worth investigating.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Research question: Which observable content and search-performance signals can help rank pages for content review? The decision is which pages should be reviewed first. The content/SEO team would act on the ranking by investigating the highest-priority pages and deciding whether to refresh, expand, protect, prune, or monitor them. A wrong recommendation could waste time and resources on a low-priority page or cause a genuinely important page to be overlooked.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv(
    "flyrank-ml-internship/data/raw/content_refresh_anonymized.csv"
)

print("Rows:", len(df))

print(
    "Declining rate:",
    round(
        df["trend_direction"].str.lower().eq("down").mean(),
        3
    )
)

print(
    "Median impressions_90d:",
    round(df["impressions_90d"].median(), 2)
)

print(
    "Median days_since_last_update:",
    round(df["days_since_last_update"].median(), 2)
)
# Out:
# Rows: 30000
# Declining rate: 0.542
# Median impressions_90d: 731.0
# Median days_since_last_update: 20.0

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# This analysis can identify observed relationships and provide directional decision-support for prioritizing pages for review. It can show which observable signals are associated with pages that appear to need attention. It cannot prove that changing a page will cause its performance to improve, and it cannot predict or explain Google's algorithm. The ranking should therefore be treated as a review aid rather than a guaranteed outcome.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
